# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
    # !apt update && apt install -y libpq-dev libsdl2-dev swig xorg-dev xvfb
    # !pip install -q -U tf-agents pyvirtualdisplay gym[atari,box2d]
    IS_COLAB = True
except Exception:
    IS_COLAB = False

# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

if not tf.config.list_physical_devices('GPU'):
    print("No GPU was detected. CNNs can be very slow without a GPU.")
    if IS_COLAB:
        print("Go to Runtime > Change runtime and select a GPU hardware accelerator.")

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)
tf.random.set_seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# To get smooth animations
import matplotlib.animation as animation
mpl.rc('animation', html='jshtml')

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "rl"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  Release
# Hit:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Get:6 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:10 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:11 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:13 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Get:15 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1,013 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [31.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,012 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,308 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [2,134 kB]
# Fetched 7,837 kB in 7s (1,198 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 22 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libpq-dev is already the newest version (12.14-0ubuntu0.20.04.1).
# libpq-dev set to manually installed.
# The following additional packages will be installed:
#   libblkid-dev libdbus-1-dev libdmx-dev libdmx1 libdrm-dev libegl1-mesa-dev
#   libffi-dev libfontenc-dev libfs-dev libfs6 libgl1-mesa-dev libgles-dev
#   libgles1 libgles2-mesa-dev libglib2.0-dev libglib2.0-dev-bin libglvnd-dev
#   libibus-1.0-dev libmount-dev libopengl-dev libpciaccess-dev libpixman-1-dev
#   libpulse-dev libselinux1-dev libsepol1-dev libsndio-dev libudev-dev
#   libwayland-bin libwayland-dev libxaw7-dev libxcomposite-dev libxcursor-dev
#   libxdamage-dev libxfixes-dev libxfont-dev libxi-dev libxinerama-dev
#   libxkbcommon-dev libxkbfile-dev libxmu-dev libxmu-headers libxmuu-dev
#   libxpm-dev libxrandr-dev libxres-dev libxres1 libxtst-dev libxv-dev
#   libxvmc-dev libxvmc1 libxxf86dga-dev libxxf86dga1 libxxf86vm-dev
#   mesa-common-dev swig4.0 x11proto-input-dev x11proto-randr-dev
#   x11proto-record-dev x11proto-xf86dga-dev x11proto-xf86vidmode-dev
#   x11proto-xinerama-dev xserver-xorg-dev
# Suggested packages:
#   libgirepository1.0-dev libglib2.0-doc libgdk-pixbuf2.0-bin
#   | libgdk-pixbuf2.0-dev libxml2-utils libwayland-doc libxaw-doc swig-doc
#   swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   libblkid-dev libdbus-1-dev libdmx-dev libdmx1 libdrm-dev libegl1-mesa-dev
#   libffi-dev libfontenc-dev libfs-dev libfs6 libgl1-mesa-dev libgles-dev
#   libgles1 libgles2-mesa-dev libglib2.0-dev libglib2.0-dev-bin libglvnd-dev
#   libibus-1.0-dev libmount-dev libopengl-dev libpciaccess-dev libpixman-1-dev
#   libpulse-dev libsdl2-dev libselinux1-dev libsepol1-dev libsndio-dev
#   libudev-dev libwayland-bin libwayland-dev libxaw7-dev libxcomposite-dev
#   libxcursor-dev libxdamage-dev libxfixes-dev libxfont-dev libxi-dev
#   libxinerama-dev libxkbcommon-dev libxkbfile-dev libxmu-dev libxmu-headers
#   libxmuu-dev libxpm-dev libxrandr-dev libxres-dev libxres1 libxtst-dev
#   libxv-dev libxvmc-dev libxvmc1 libxxf86dga-dev libxxf86dga1 libxxf86vm-dev
#   mesa-common-dev swig swig4.0 x11proto-input-dev x11proto-randr-dev
#   x11proto-record-dev x11proto-xf86dga-dev x11proto-xf86vidmode-dev
#   x11proto-xinerama-dev xorg-dev xserver-xorg-dev xvfb
# 0 upgraded, 66 newly installed, 0 to remove and 22 not upgraded.
# Need to get 9,014 kB of archives.
# After this operation, 44.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdbus-1-dev amd64 1.12.16-2ubuntu2.3 [167 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libdmx1 amd64 1:1.1.4-2 [9,356 B]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 libdmx-dev amd64 1:1.1.4-2 [33.0 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 libpciaccess-dev amd64 0.16-0ubuntu1 [20.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdrm-dev amd64 2.4.107-8ubuntu1~20.04.2 [131 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgles1 amd64 1.3.2-1~ubuntu0.20.04.2 [10.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgles-dev amd64 1.3.2-1~ubuntu0.20.04.2 [47.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libopengl-dev amd64 1.3.2-1~ubuntu0.20.04.2 [3,584 B]
# Get:9 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglvnd-dev amd64 1.3.2-1~ubuntu0.20.04.2 [11.6 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libegl1-mesa-dev amd64 21.2.6-0ubuntu0.1~20.04.2 [7,760 B]
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 libfontenc-dev amd64 1:1.1.4-0ubuntu1 [14.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/main amd64 libfs6 amd64 2:1.0.7-1 [22.5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/main amd64 libfs-dev amd64 2:1.0.7-1 [26.8 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgles2-mesa-dev amd64 21.2.6-0ubuntu0.1~20.04.2 [6,424 B]
# Get:15 http://archive.ubuntu.com/ubuntu focal/main amd64 libffi-dev amd64 3.3-4 [57.0 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-dev-bin amd64 2.64.6-1~ubuntu20.04.4 [109 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libblkid-dev amd64 2.34-0.1ubuntu9.3 [167 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libmount-dev amd64 2.34-0.1ubuntu9.3 [176 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsepol1-dev amd64 3.0-1ubuntu0.1 [325 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/main amd64 libselinux1-dev amd64 3.0-1build2 [151 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-dev amd64 2.64.6-1~ubuntu20.04.4 [1,506 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libibus-1.0-dev amd64 1.5.22-2ubuntu2.1 [179 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpixman-1-dev amd64 0.38.4-0ubuntu2.1 [243 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpulse-dev amd64 1:13.99.1-1ubuntu3.13 [72.5 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgl1-mesa-dev amd64 21.2.6-0ubuntu0.1~20.04.2 [6,420 B]
# Get:26 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsndio-dev amd64 1.5.0-3 [13.6 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libudev-dev amd64 245.4-4ubuntu3.19 [19.7 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwayland-bin amd64 1.18.0-1ubuntu0.1 [20.2 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwayland-dev amd64 1.18.0-1ubuntu0.1 [64.6 kB]
# Get:30 http://archive.ubuntu.com/ubuntu focal/main amd64 libxfixes-dev amd64 1:5.0.3-2 [11.4 kB]
# Get:31 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcursor-dev amd64 1:1.2.0-2 [26.5 kB]
# Get:32 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-input-dev all 2019.2-1ubuntu1 [2,628 B]
# Get:33 http://archive.ubuntu.com/ubuntu focal/main amd64 libxi-dev amd64 2:1.7.10-0ubuntu1 [187 kB]
# Get:34 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-xinerama-dev all 2019.2-1ubuntu1 [2,628 B]
# Get:35 http://archive.ubuntu.com/ubuntu focal/main amd64 libxinerama-dev amd64 2:1.1.4-2 [7,896 B]
# Get:36 http://archive.ubuntu.com/ubuntu focal/main amd64 libxkbcommon-dev amd64 0.10.0-1 [45.4 kB]
# Get:37 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-randr-dev all 2019.2-1ubuntu1 [2,620 B]
# Get:38 http://archive.ubuntu.com/ubuntu focal/main amd64 libxrandr-dev amd64 2:1.5.2-0ubuntu1 [25.0 kB]
# Get:39 http://archive.ubuntu.com/ubuntu focal/main amd64 libxv-dev amd64 2:1.0.11-1 [32.5 kB]
# Get:40 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-xf86vidmode-dev all 2019.2-1ubuntu1 [2,624 B]
# Get:41 http://archive.ubuntu.com/ubuntu focal/main amd64 libxxf86vm-dev amd64 1:1.1.4-1build1 [13.3 kB]
# Get:42 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsdl2-dev amd64 2.0.10+dfsg1-3 [718 kB]
# Get:43 http://archive.ubuntu.com/ubuntu focal/main amd64 libxmu-headers all 2:1.1.3-0ubuntu1 [54.2 kB]
# Get:44 http://archive.ubuntu.com/ubuntu focal/main amd64 libxmu-dev amd64 2:1.1.3-0ubuntu1 [49.9 kB]
# Get:45 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libxpm-dev amd64 1:3.5.12-1ubuntu0.20.04.1 [88.0 kB]
# Get:46 http://archive.ubuntu.com/ubuntu focal/main amd64 libxaw7-dev amd64 2:1.0.13-1 [231 kB]
# Get:47 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcomposite-dev amd64 1:0.4.5-1 [9,152 B]
# Get:48 http://archive.ubuntu.com/ubuntu focal/main amd64 libxdamage-dev amd64 1:1.1.5-2 [5,228 B]
# Get:49 http://archive.ubuntu.com/ubuntu focal/main amd64 libxfont-dev amd64 1:2.0.3-1 [118 kB]
# Get:50 http://archive.ubuntu.com/ubuntu focal/main amd64 libxkbfile-dev amd64 1:1.1.0-1 [74.7 kB]
# Get:51 http://archive.ubuntu.com/ubuntu focal/main amd64 libxmuu-dev amd64 2:1.1.3-0ubuntu1 [7,464 B]
# Get:52 http://archive.ubuntu.com/ubuntu focal/main amd64 libxres1 amd64 2:1.2.0-4 [7,584 B]
# Get:53 http://archive.ubuntu.com/ubuntu focal/main amd64 libxres-dev amd64 2:1.2.0-4 [8,332 B]
# Get:54 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-record-dev all 2019.2-1ubuntu1 [2,624 B]
# Get:55 http://archive.ubuntu.com/ubuntu focal/main amd64 libxtst-dev amd64 2:1.2.3-1 [15.2 kB]
# Get:56 http://archive.ubuntu.com/ubuntu focal/main amd64 libxvmc1 amd64 2:1.0.12-2 [14.2 kB]
# Get:57 http://archive.ubuntu.com/ubuntu focal/main amd64 libxvmc-dev amd64 2:1.0.12-2 [23.1 kB]
# Get:58 http://archive.ubuntu.com/ubuntu focal/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu1 [12.0 kB]
# Get:59 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-xf86dga-dev all 2019.2-1ubuntu1 [2,628 B]
# Get:60 http://archive.ubuntu.com/ubuntu focal/main amd64 libxxf86dga-dev amd64 2:1.1.5-0ubuntu1 [15.9 kB]
# Get:61 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 mesa-common-dev amd64 21.2.6-0ubuntu0.1~20.04.2 [1,504 kB]
# Get:62 http://archive.ubuntu.com/ubuntu focal/universe amd64 swig4.0 amd64 4.0.1-5build1 [1,081 kB]
# Get:63 http://archive.ubuntu.com/ubuntu focal/universe amd64 swig all 4.0.1-5build1 [5,528 B]
# Get:64 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 xserver-xorg-dev amd64 2:1.20.13-1ubuntu1~20.04.6 [201 kB]
# Get:65 http://archive.ubuntu.com/ubuntu focal/main amd64 xorg-dev all 1:7.7+19ubuntu14 [4,212 B]
# Get:66 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 xvfb amd64 2:1.20.13-1ubuntu1~20.04.6 [780 kB]
# Fetched 9,014 kB in 8s (1,116 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package libdbus-1-dev:amd64.
# (Reading database ... 128215 files and directories currently installed.)
# Preparing to unpack .../00-libdbus-1-dev_1.12.16-2ubuntu2.3_amd64.deb ...
# Unpacking libdbus-1-dev:amd64 (1.12.16-2ubuntu2.3) ...
# Selecting previously unselected package libdmx1:amd64.
# Preparing to unpack .../01-libdmx1_1%3a1.1.4-2_amd64.deb ...
# Unpacking libdmx1:amd64 (1:1.1.4-2) ...
# Selecting previously unselected package libdmx-dev:amd64.
# Preparing to unpack .../02-libdmx-dev_1%3a1.1.4-2_amd64.deb ...
# Unpacking libdmx-dev:amd64 (1:1.1.4-2) ...
# Selecting previously unselected package libpciaccess-dev:amd64.
# Preparing to unpack .../03-libpciaccess-dev_0.16-0ubuntu1_amd64.deb ...
# Unpacking libpciaccess-dev:amd64 (0.16-0ubuntu1) ...
# Selecting previously unselected package libdrm-dev:amd64.
# Preparing to unpack .../04-libdrm-dev_2.4.107-8ubuntu1~20.04.2_amd64.deb ...
# Unpacking libdrm-dev:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../05-libgles1_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libgles1:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../06-libgles-dev_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../07-libopengl-dev_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../08-libglvnd-dev_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package libegl1-mesa-dev:amd64.
# Preparing to unpack .../09-libegl1-mesa-dev_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking libegl1-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libfontenc-dev:amd64.
# Preparing to unpack .../10-libfontenc-dev_1%3a1.1.4-0ubuntu1_amd64.deb ...
# Unpacking libfontenc-dev:amd64 (1:1.1.4-0ubuntu1) ...
# Selecting previously unselected package libfs6:amd64.
# Preparing to unpack .../11-libfs6_2%3a1.0.7-1_amd64.deb ...
# Unpacking libfs6:amd64 (2:1.0.7-1) ...
# Selecting previously unselected package libfs-dev:amd64.
# Preparing to unpack .../12-libfs-dev_2%3a1.0.7-1_amd64.deb ...
# Unpacking libfs-dev:amd64 (2:1.0.7-1) ...
# Selecting previously unselected package libgles2-mesa-dev:amd64.
# Preparing to unpack .../13-libgles2-mesa-dev_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking libgles2-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../14-libffi-dev_3.3-4_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.3-4) ...
# Selecting previously unselected package libglib2.0-dev-bin.
# Preparing to unpack .../15-libglib2.0-dev-bin_2.64.6-1~ubuntu20.04.4_amd64.deb ...
# Unpacking libglib2.0-dev-bin (2.64.6-1~ubuntu20.04.4) ...
# Selecting previously unselected package libblkid-dev:amd64.
# Preparing to unpack .../16-libblkid-dev_2.34-0.1ubuntu9.3_amd64.deb ...
# Unpacking libblkid-dev:amd64 (2.34-0.1ubuntu9.3) ...
# Selecting previously unselected package libmount-dev:amd64.
# Preparing to unpack .../17-libmount-dev_2.34-0.1ubuntu9.3_amd64.deb ...
# Unpacking libmount-dev:amd64 (2.34-0.1ubuntu9.3) ...
# Selecting previously unselected package libsepol1-dev:amd64.
# Preparing to unpack .../18-libsepol1-dev_3.0-1ubuntu0.1_amd64.deb ...
# Unpacking libsepol1-dev:amd64 (3.0-1ubuntu0.1) ...
# Selecting previously unselected package libselinux1-dev:amd64.
# Preparing to unpack .../19-libselinux1-dev_3.0-1build2_amd64.deb ...
# Unpacking libselinux1-dev:amd64 (3.0-1build2) ...
# Selecting previously unselected package libglib2.0-dev:amd64.
# Preparing to unpack .../20-libglib2.0-dev_2.64.6-1~ubuntu20.04.4_amd64.deb ...
# Unpacking libglib2.0-dev:amd64 (2.64.6-1~ubuntu20.04.4) ...
# Selecting previously unselected package libibus-1.0-dev:amd64.
# Preparing to unpack .../21-libibus-1.0-dev_1.5.22-2ubuntu2.1_amd64.deb ...
# Unpacking libibus-1.0-dev:amd64 (1.5.22-2ubuntu2.1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../22-libpixman-1-dev_0.38.4-0ubuntu2.1_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.38.4-0ubuntu2.1) ...
# Selecting previously unselected package libpulse-dev:amd64.
# Preparing to unpack .../23-libpulse-dev_1%3a13.99.1-1ubuntu3.13_amd64.deb ...
# Unpacking libpulse-dev:amd64 (1:13.99.1-1ubuntu3.13) ...
# Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../24-libgl1-mesa-dev_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libsndio-dev:amd64.
# Preparing to unpack .../25-libsndio-dev_1.5.0-3_amd64.deb ...
# Unpacking libsndio-dev:amd64 (1.5.0-3) ...
# Selecting previously unselected package libudev-dev:amd64.
# Preparing to unpack .../26-libudev-dev_245.4-4ubuntu3.19_amd64.deb ...
# Unpacking libudev-dev:amd64 (245.4-4ubuntu3.19) ...
# Selecting previously unselected package libwayland-bin.
# Preparing to unpack .../27-libwayland-bin_1.18.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-bin (1.18.0-1ubuntu0.1) ...
# Selecting previously unselected package libwayland-dev:amd64.
# Preparing to unpack .../28-libwayland-dev_1.18.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-dev:amd64 (1.18.0-1ubuntu0.1) ...
# Selecting previously unselected package libxfixes-dev:amd64.
# Preparing to unpack .../29-libxfixes-dev_1%3a5.0.3-2_amd64.deb ...
# Unpacking libxfixes-dev:amd64 (1:5.0.3-2) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../30-libxcursor-dev_1%3a1.2.0-2_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.2.0-2) ...
# Selecting previously unselected package x11proto-input-dev.
# Preparing to unpack .../31-x11proto-input-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-input-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package libxi-dev:amd64.
# Preparing to unpack .../32-libxi-dev_2%3a1.7.10-0ubuntu1_amd64.deb ...
# Unpacking libxi-dev:amd64 (2:1.7.10-0ubuntu1) ...
# Selecting previously unselected package x11proto-xinerama-dev.
# Preparing to unpack .../33-x11proto-xinerama-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-xinerama-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../34-libxinerama-dev_2%3a1.1.4-2_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.4-2) ...
# Selecting previously unselected package libxkbcommon-dev:amd64.
# Preparing to unpack .../35-libxkbcommon-dev_0.10.0-1_amd64.deb ...
# Unpacking libxkbcommon-dev:amd64 (0.10.0-1) ...
# Selecting previously unselected package x11proto-randr-dev.
# Preparing to unpack .../36-x11proto-randr-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-randr-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../37-libxrandr-dev_2%3a1.5.2-0ubuntu1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.2-0ubuntu1) ...
# Selecting previously unselected package libxv-dev:amd64.
# Preparing to unpack .../38-libxv-dev_2%3a1.0.11-1_amd64.deb ...
# Unpacking libxv-dev:amd64 (2:1.0.11-1) ...
# Selecting previously unselected package x11proto-xf86vidmode-dev.
# Preparing to unpack .../39-x11proto-xf86vidmode-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-xf86vidmode-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package libxxf86vm-dev:amd64.
# Preparing to unpack .../40-libxxf86vm-dev_1%3a1.1.4-1build1_amd64.deb ...
# Unpacking libxxf86vm-dev:amd64 (1:1.1.4-1build1) ...
# Selecting previously unselected package libsdl2-dev:amd64.
# Preparing to unpack .../41-libsdl2-dev_2.0.10+dfsg1-3_amd64.deb ...
# Unpacking libsdl2-dev:amd64 (2.0.10+dfsg1-3) ...
# Selecting previously unselected package libxmu-headers.
# Preparing to unpack .../42-libxmu-headers_2%3a1.1.3-0ubuntu1_all.deb ...
# Unpacking libxmu-headers (2:1.1.3-0ubuntu1) ...
# Selecting previously unselected package libxmu-dev:amd64.
# Preparing to unpack .../43-libxmu-dev_2%3a1.1.3-0ubuntu1_amd64.deb ...
# Unpacking libxmu-dev:amd64 (2:1.1.3-0ubuntu1) ...
# Selecting previously unselected package libxpm-dev:amd64.
# Preparing to unpack .../44-libxpm-dev_1%3a3.5.12-1ubuntu0.20.04.1_amd64.deb ...
# Unpacking libxpm-dev:amd64 (1:3.5.12-1ubuntu0.20.04.1) ...
# Selecting previously unselected package libxaw7-dev:amd64.
# Preparing to unpack .../45-libxaw7-dev_2%3a1.0.13-1_amd64.deb ...
# Unpacking libxaw7-dev:amd64 (2:1.0.13-1) ...
# Selecting previously unselected package libxcomposite-dev:amd64.
# Preparing to unpack .../46-libxcomposite-dev_1%3a0.4.5-1_amd64.deb ...
# Unpacking libxcomposite-dev:amd64 (1:0.4.5-1) ...
# Selecting previously unselected package libxdamage-dev:amd64.
# Preparing to unpack .../47-libxdamage-dev_1%3a1.1.5-2_amd64.deb ...
# Unpacking libxdamage-dev:amd64 (1:1.1.5-2) ...
# Selecting previously unselected package libxfont-dev.
# Preparing to unpack .../48-libxfont-dev_1%3a2.0.3-1_amd64.deb ...
# Unpacking libxfont-dev (1:2.0.3-1) ...
# Selecting previously unselected package libxkbfile-dev:amd64.
# Preparing to unpack .../49-libxkbfile-dev_1%3a1.1.0-1_amd64.deb ...
# Unpacking libxkbfile-dev:amd64 (1:1.1.0-1) ...
# Selecting previously unselected package libxmuu-dev:amd64.
# Preparing to unpack .../50-libxmuu-dev_2%3a1.1.3-0ubuntu1_amd64.deb ...
# Unpacking libxmuu-dev:amd64 (2:1.1.3-0ubuntu1) ...
# Selecting previously unselected package libxres1:amd64.
# Preparing to unpack .../51-libxres1_2%3a1.2.0-4_amd64.deb ...
# Unpacking libxres1:amd64 (2:1.2.0-4) ...
# Selecting previously unselected package libxres-dev:amd64.
# Preparing to unpack .../52-libxres-dev_2%3a1.2.0-4_amd64.deb ...
# Unpacking libxres-dev:amd64 (2:1.2.0-4) ...
# Selecting previously unselected package x11proto-record-dev.
# Preparing to unpack .../53-x11proto-record-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-record-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package libxtst-dev:amd64.
# Preparing to unpack .../54-libxtst-dev_2%3a1.2.3-1_amd64.deb ...
# Unpacking libxtst-dev:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package libxvmc1:amd64.
# Preparing to unpack .../55-libxvmc1_2%3a1.0.12-2_amd64.deb ...
# Unpacking libxvmc1:amd64 (2:1.0.12-2) ...
# Selecting previously unselected package libxvmc-dev:amd64.
# Preparing to unpack .../56-libxvmc-dev_2%3a1.0.12-2_amd64.deb ...
# Unpacking libxvmc-dev:amd64 (2:1.0.12-2) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../57-libxxf86dga1_2%3a1.1.5-0ubuntu1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu1) ...
# Selecting previously unselected package x11proto-xf86dga-dev.
# Preparing to unpack .../58-x11proto-xf86dga-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-xf86dga-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package libxxf86dga-dev:amd64.
# Preparing to unpack .../59-libxxf86dga-dev_2%3a1.1.5-0ubuntu1_amd64.deb ...
# Unpacking libxxf86dga-dev:amd64 (2:1.1.5-0ubuntu1) ...
# Selecting previously unselected package mesa-common-dev:amd64.
# Preparing to unpack .../60-mesa-common-dev_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking mesa-common-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package swig4.0.
# Preparing to unpack .../61-swig4.0_4.0.1-5build1_amd64.deb ...
# Unpacking swig4.0 (4.0.1-5build1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../62-swig_4.0.1-5build1_all.deb ...
# Unpacking swig (4.0.1-5build1) ...
# Selecting previously unselected package xserver-xorg-dev.
# Preparing to unpack .../63-xserver-xorg-dev_2%3a1.20.13-1ubuntu1~20.04.6_amd64.deb ...
# Unpacking xserver-xorg-dev (2:1.20.13-1ubuntu1~20.04.6) ...
# Selecting previously unselected package xorg-dev.
# Preparing to unpack .../64-xorg-dev_1%3a7.7+19ubuntu14_all.deb ...
# Unpacking xorg-dev (1:7.7+19ubuntu14) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../65-xvfb_2%3a1.20.13-1ubuntu1~20.04.6_amd64.deb ...
# Unpacking xvfb (2:1.20.13-1ubuntu1~20.04.6) ...
# Setting up libglib2.0-dev-bin (2.64.6-1~ubuntu20.04.4) ...
# Setting up libblkid-dev:amd64 (2.34-0.1ubuntu9.3) ...
# Setting up libxmu-headers (2:1.1.3-0ubuntu1) ...
# Setting up libsndio-dev:amd64 (1.5.0-3) ...
# Setting up libpixman-1-dev:amd64 (0.38.4-0ubuntu2.1) ...
# Setting up libpciaccess-dev:amd64 (0.16-0ubuntu1) ...
# Setting up x11proto-randr-dev (2019.2-1ubuntu1) ...
# Setting up xvfb (2:1.20.13-1ubuntu1~20.04.6) ...
# Setting up libxkbcommon-dev:amd64 (0.10.0-1) ...
# Setting up libsepol1-dev:amd64 (3.0-1ubuntu0.1) ...
# Setting up libfontenc-dev:amd64 (1:1.1.4-0ubuntu1) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu1) ...
# Setting up libxmu-dev:amd64 (2:1.1.3-0ubuntu1) ...
# Setting up libffi-dev:amd64 (3.3-4) ...
# Setting up libxvmc1:amd64 (2:1.0.12-2) ...
# Setting up x11proto-xinerama-dev (2019.2-1ubuntu1) ...
# Setting up libxfixes-dev:amd64 (1:5.0.3-2) ...
# Setting up libxv-dev:amd64 (2:1.0.11-1) ...
# Setting up libwayland-bin (1.18.0-1ubuntu0.1) ...
# Setting up libxrandr-dev:amd64 (2:1.5.2-0ubuntu1) ...
# Setting up libdbus-1-dev:amd64 (1.12.16-2ubuntu2.3) ...
# Setting up libdmx1:amd64 (1:1.1.4-2) ...
# Setting up libdmx-dev:amd64 (1:1.1.4-2) ...
# Setting up libgles1:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up libxpm-dev:amd64 (1:3.5.12-1ubuntu0.20.04.1) ...
# Setting up x11proto-input-dev (2019.2-1ubuntu1) ...
# Setting up libudev-dev:amd64 (245.4-4ubuntu3.19) ...
# Setting up libxinerama-dev:amd64 (2:1.1.4-2) ...
# Setting up x11proto-xf86vidmode-dev (2019.2-1ubuntu1) ...
# Setting up libfs6:amd64 (2:1.0.7-1) ...
# Setting up libxaw7-dev:amd64 (2:1.0.13-1) ...
# Setting up x11proto-record-dev (2019.2-1ubuntu1) ...
# Setting up libopengl-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up libgles-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up swig4.0 (4.0.1-5build1) ...
# Setting up x11proto-xf86dga-dev (2019.2-1ubuntu1) ...
# Setting up libxi-dev:amd64 (2:1.7.10-0ubuntu1) ...
# Setting up libxmuu-dev:amd64 (2:1.1.3-0ubuntu1) ...
# Setting up libmount-dev:amd64 (2.34-0.1ubuntu9.3) ...
# Setting up libxres1:amd64 (2:1.2.0-4) ...
# Setting up libxvmc-dev:amd64 (2:1.0.12-2) ...
# Setting up libxtst-dev:amd64 (2:1.2.3-1) ...
# Setting up libxkbfile-dev:amd64 (1:1.1.0-1) ...
# Setting up libxdamage-dev:amd64 (1:1.1.5-2) ...
# Setting up libdrm-dev:amd64 (2.4.107-8ubuntu1~20.04.2) ...
# Setting up swig (4.0.1-5build1) ...
# Setting up libselinux1-dev:amd64 (3.0-1build2) ...
# Setting up libxcomposite-dev:amd64 (1:0.4.5-1) ...
# Setting up libxcursor-dev:amd64 (1:1.2.0-2) ...
# Setting up libxxf86dga-dev:amd64 (2:1.1.5-0ubuntu1) ...
# Setting up libxxf86vm-dev:amd64 (1:1.1.4-1build1) ...
# Setting up libxfont-dev (1:2.0.3-1) ...
# Setting up libglvnd-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up libwayland-dev:amd64 (1.18.0-1ubuntu0.1) ...
# Setting up libglib2.0-dev:amd64 (2.64.6-1~ubuntu20.04.4) ...
# Setting up libfs-dev:amd64 (2:1.0.7-1) ...
# Setting up libgl1-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up libxres-dev:amd64 (2:1.2.0-4) ...
# Setting up mesa-common-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up libegl1-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up libgles2-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up xserver-xorg-dev (2:1.20.13-1ubuntu1~20.04.6) ...
# Setting up xorg-dev (1:7.7+19ubuntu14) ...
# Processing triggers for libglib2.0-0:amd64 (2.64.6-1~ubuntu20.04.4) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Setting up libibus-1.0-dev:amd64 (1.5.22-2ubuntu2.1) ...
# Setting up libpulse-dev:amd64 (1:13.99.1-1ubuntu3.13) ...
# Setting up libsdl2-dev:amd64 (2.0.10+dfsg1-3) ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 29.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 KB 51.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.4/624.4 KB 31.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 43.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.9/719.9 KB 59.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 710.3/710.3 KB 51.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 734.5/734.5 KB 56.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 732.2/732.2 KB 50.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 720.4/720.4 KB 53.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 696.4/696.4 KB 42.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 694.4/694.4 KB 51.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 626.2/626.2 KB 34.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 KB 31.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 78.1 MB/s eta 0:00:00
#   Building wheel for box2d-py (setup.py) ... done
#   Building wheel for gym (pyproject.toml) ... done

# %%
import gym
import math
env = gym.make('Pendulum-v1')
env.seed(42)
obs = env.reset()
obs
# Out:
# array([-0.14995256,  0.9886932 , -0.12224312], dtype=float32)

# %%
try:
    import pyvirtualdisplay
    display = pyvirtualdisplay.Display(visible=0, size=(1400, 900)).start()
except ImportError:
    pass

env.render()
# Out:
# True

# %%
img = env.render(mode="rgb_array")
img.shape
# Out:
# (500, 500, 3)

# %%
def plot_environment(env, figsize=(5,4)):
    plt.figure(figsize=figsize)
    img = env.render(mode="rgb_array")
    plt.imshow(img)
    plt.axis("off")
    return img

# %%
plot_environment(env)
plt.show()

# %%
env.action_space
#(#to render, -max torque, max torque)
# Out:
# Box(-2.0, 2.0, (1,), float32)

# %%
action = (-1, 9, 5)  # accelerate right
obs, reward, done, info = env.step(action)
obs
plot_environment(env)
save_fig("cart_pole_plot")
# Out:
# Saving figure cart_pole_plot

# %%
# cos(theta) is x, sin(theta) is y, theta dot is velocity
# theta is angle from bottom
obs
# Out:
# array([-0.1731077,  0.9849029,  0.4692768], dtype=float32)

# %%
def update_scene(num, frames, patch):
    patch.set_data(frames[num])
    return patch,

def plot_animation(frames, repeat=False, interval=40):
    fig = plt.figure()
    patch = plt.imshow(frames[0])
    plt.axis('off')
    anim = animation.FuncAnimation(
        fig, update_scene, fargs=(frames, patch),
        frames=len(frames), repeat=repeat, interval=interval)
    plt.close()
    return anim

# %%
env.reset()
env.seed(42)

def basic_policy(obs):
    theta = np.arccos(obs[0])
    theta = theta * 180 / np.pi
    thetaDot = obs[2]
    return [1] if theta < 0 and thetaDot < 1 else [1]



totals = []
for episode in range(500):
    episode_rewards = 0
    obs = env.reset()
    for step in range(200):
        action = basic_policy(obs)
        obs, reward, done, info = env.step(action)
        episode_rewards += reward
        if done:
            break
    totals.append(episode_rewards)

# %%
env.seed(42)

frames = []

obs = env.reset()
for step in range(200):
    img = env.render(mode="rgb_array")
    frames.append(img)
    action = basic_policy(obs)

    obs, reward, done, info = env.step(action)
    if done:
        break

# %%
plot_animation(frames)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img2fb7c3bce55943a5a4804ff57076c6ed">
#   <div class="anim-controls">
#     <input id="_anim_slider2fb7c3bce55943a5a4804ff57076c6ed" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim2fb7c3bce55943a5a4804ff57076c6ed.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim2fb7c3bce55943a5a4804ff57076c6ed.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim2fb7c3bce55943a5a4804ff57076c6ed.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim2fb7c3bce55943a5a4804ff57076c6ed.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim2fb7c3bce55943a5a4804ff57076c6ed.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim2fb7c3bce55943a5a4804ff57076c6ed.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim2fb7c3bce55943a5a4804ff57076c6ed.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim2fb7c3bce55943a5a4804ff57076c6ed.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim2fb7c3bce55943a5a4804ff57076c6ed.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim2fb7c3bce55943a5a4804ff57076c6ed.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select2fb7c3bce55943a5a4804ff57076c6ed"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_2fb7c3bce55943a5a4804ff57076c6ed"
#              checked>
#       <label for="_anim_radio1_2fb7c3bce55943a5a4804ff57076c6ed">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_2fb7c3bce55943a5a4804ff57076c6ed"
#              >
#       <label for="_anim_radio2_2fb7c3bce55943a5a4804ff57076c6ed">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_2fb7c3bce55943a5a4804ff57076c6ed"
#              >
#       <label for="_anim_radio3_2fb7c3bce55943a5a4804ff57076c6ed">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img2fb7c3bce55943a5a4804ff57076c6ed";
#     var slider_id = "_anim_slider2fb7c3bce55943a5a4804ff57076c6ed";
#     var loop_select_id = "_anim_loop_select2fb7c3bce55943a5a4804ff57076c6ed";
#     var frames = new Array(200);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjUuMywgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/NK7nSAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAJIElE

# %%
print(obs)
np.mean(totals), np.std(totals), np.min(totals), np.max(totals)
# Out:
# [-0.47773376  0.87850467 -4.26927584]
# (-1331.2166308835886,
#  236.23178099272297,
#  -1739.0391616164245,
#  -597.1009774165669)
